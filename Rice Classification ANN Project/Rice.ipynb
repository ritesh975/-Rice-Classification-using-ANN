# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("riceClassification.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 0          1  4537        92.229316        64.012769      0.719916
# 1          2  2872        74.691881        51.400454      0.725553
# 2          3  3048        76.293164        52.043491      0.731211
# 3          4  3073        77.033628        51.928487      0.738639
# 4          5  3693        85.124785        56.374021      0.749282
# ...      ...   ...              ...              ...           ...
# 18180  18181  5853       148.624571        51.029281      0.939210
# 18181  18182  7585       169.593996        58.141659      0.939398
# 18182  18183  6365       154.777085        52.908085      0.939760
# 18183  18184  5960       151.397924        51.474600      0.940427
# 18184  18185  6134       153.081981        51.590606      0.941500
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  \
# 0            4677      76.004525  0.657536    273.085   0.764510
# 1            3015      60.471018  0.713009    208.317   0.831658
# 2            3132      62.296341  0.759153    210.012   0.868434
# 3            3157      62.551300  0.783529    210.657   0.870203
# 4            3802      68.571668  0.769375    230.332   0.874743
# ...           ...            ...       ...        ...        ...
# 18180        6008      86.326537  0.498594    332.960   0.663444
# 18181        7806      98.272692  0.647461    385.506   0.641362
# 18182        6531      90.023162  0.561287    342.253   0.682832
# 18183        6189      87.112041  0.492399    343.371   0.635227
# 18184        6283      88.374495  0.489975    338.613   0.672274
#
#        AspectRation  Class
# 0          1.440796      1
# 1          1.453137      1
# 2          1.465950      1
# 3          1.483456      1
# 4          1.510000      1
# ...             ...    ...
# 18180      2.912535      0
# 18181      2.916910      0
# 18182      2.925396      0
# 18183      2.941216      0
# 18184      2.967245      0
#
# [18185 rows x 12 columns]>

# %%
df.shape
# Out:
# (18185, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18185 entries, 0 to 18184
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               18185 non-null  int64
#  1   Area             18185 non-null  int64
#  2   MajorAxisLength  18185 non-null  float64
#  3   MinorAxisLength  18185 non-null  float64
#  4   Eccentricity     18185 non-null  float64
#  5   ConvexArea       18185 non-null  int64
#  6   EquivDiameter    18185 non-null  float64
#  7   Extent           18185 non-null  float64
#  8   Perimeter        18185 non-null  float64
#  9   Roundness        18185 non-null  float64
#  10  AspectRation     18185 non-null  float64
#  11  Class            18185 non-null  int64
# dtypes: float64(8), int64(4)
# memory usage: 1.7 MB

# %%
df['Class'].value_counts()
# Out:
# Class
# 1    9985
# 0    8200
# Name: count, dtype: int64

# %%
df = df.drop('id', axis=1)

# %%
df.head()
# Out:
#    Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  4537        92.229316        64.012769      0.719916        4677
# 1  2872        74.691881        51.400454      0.725553        3015
# 2  3048        76.293164        52.043491      0.731211        3132
# 3  3073        77.033628        51.928487      0.738639        3157
# 4  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
X.shape
# Out:
# (18185, 10)

# %%
y.shape
# Out:
# (18185,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (14548, 10)
# X_test: (3637, 10)
# y_train: (14548,)
# y_test: (3637,)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential()

model.add(Input(shape=(X_train.shape[1],)))

model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Layer (type)          ┃ Output Shape    ┃  Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ dense (Dense)         │ (None, 64)      │      704 │
# ├───────────────────────┼─────────────────┼──────────┤
# │ dense_1 (Dense)       │ (None, 32)      │    2,080 │
# ├───────────────────────┼─────────────────┼──────────┤
# │ dense_2 (Dense)       │ (None, 16)      │      528 │
# ├───────────────────────┼─────────────────┼──────────┤
# │ dense_3 (Dense)       │ (None, 1)       │       17 │
# └───────────────────────┴─────────────────┴──────────┘
#  Total params: 3,329 (13.00 KB)
#  Trainable params: 3,329 (13.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9768 - loss: 0.0931 - val_accuracy: 0.9835 - val_loss: 0.0488
# Epoch 2/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9884 - loss: 0.0353 - val_accuracy: 0.9845 - val_loss: 0.0453
# Epoch 3/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0344 - val_accuracy: 0.9852 - val_loss: 0.0447
# Epoch 4/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9887 - loss: 0.0336 - val_accuracy: 0.9845 - val_loss: 0.0479
# Epoch 5/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9891 - loss: 0.0329 - val_accuracy: 0.9856 - val_loss: 0.0458
# Epoch 6/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9888 - loss: 0.0321 - val_accuracy: 0.9863 - val_loss: 0.0431
# Epoch 7/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9886 - loss: 0.0327 - val_accuracy: 0.9856 - val_loss: 0.0438
# Epoch 8/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9894 - loss: 0.0317 - val_accuracy: 0.9856 - val_loss: 0.0478
# Epoch 9/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9897 - loss: 0.0317 - val_accuracy: 0.9856 - val_loss: 0.0426
# Epoch 10/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9887 - loss: 0.0316 - val_accuracy: 0.9869 - val_loss: 0.0468
# Epoch 11/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9894 - loss: 0.0311 - val_accuracy: 0.9849 - val_loss: 0.0438
# Epoch 12/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9900 - loss: 0.0307 - val_accuracy: 0.9852 - val_loss: 0.0419
# Epoch 13/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9899 - loss: 0.0308 - val_accuracy: 0.9856 - val_loss: 0.0410
# Epoch 14/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0305 - val_accuracy: 0.9856 - val_loss: 0.0408
# Epoch 15/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9903 - loss: 0.0305 - val_accuracy: 0.9863 - val_loss: 0.0411
# Epoch 16/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9898 - loss: 0.0308 - val_accuracy: 0.9869 - val_loss: 0.0399
# Epoch 17/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9904 - loss: 0.0298 - val_accuracy: 0.9866 - val_loss: 0.0403
# Epoch 18/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9904 - loss: 0.0300 - val_accuracy: 0.9849 - val_loss: 0.0406
# Epoch 19/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9901 - loss: 0.0297 - val_accuracy: 0.9859 - val_loss: 0.0399
# Epoch 20/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9903 - loss: 0.0298 - val_accuracy: 0.9852 - val_loss: 0.0415
# Epoch 21/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0297 - val_accuracy: 0.9863 - val_loss: 0.0394
# Epoch 22/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9905 - loss: 0.0292 - val_accuracy: 0.9856 - val_loss: 0.0404
# Epoch 23/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9897 - loss: 0.0290 - val_accuracy: 0.9863 - val_loss: 0.0391
# Epoch 24/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0288 - val_accuracy: 0.9856 - val_loss: 0.0385
# Epoch 25/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9904 - loss: 0.0288 - val_accuracy: 0.9863 - val_loss: 0.0381
# Epoch 26/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9902 - loss: 0.0291 - val_accuracy: 0.9869 - val_loss: 0.0383
# Epoch 27/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9905 - loss: 0.0286 - val_accuracy: 0.9859 - val_loss: 0.0387
# Epoch 28/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0283 - val_accuracy: 0.9873 - val_loss: 0.0392
# Epoch 29/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0282 - val_accuracy: 0.9866 - val_loss: 0.0402
# Epoch 30/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9907 - loss: 0.0289 - val_accuracy: 0.9869 - val_loss: 0.0373
# Epoch 31/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0281 - val_accuracy: 0.9852 - val_loss: 0.0413
# Epoch 32/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0279 - val_accuracy: 0.9866 - val_loss: 0.0391
# Epoch 33/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0275 - val_accuracy: 0.9873 - val_loss: 0.0386
# Epoch 34/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0277 - val_accuracy: 0.9866 - val_loss: 0.0378
# Epoch 35/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0276 - val_accuracy: 0.9893 - val_loss: 0.0380
# Epoch 36/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0274 - val_accuracy: 0.9869 - val_loss: 0.0383
# Epoch 37/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9916 - loss: 0.0275 - val_accuracy: 0.9873 - val_loss: 0.0390
# Epoch 38/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9913 - loss: 0.0276 - val_accuracy: 0.9859 - val_loss: 0.0411
# Epoch 39/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9912 - loss: 0.0271 - val_accuracy: 0.9866 - val_loss: 0.0408
# Epoch 40/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0272 - val_accuracy: 0.9873 - val_loss: 0.0387
# Epoch 41/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0270 - val_accuracy: 0.9873 - val_loss: 0.0384
# Epoch 42/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9919 - loss: 0.0268 - val_accuracy: 0.9883 - val_loss: 0.0373
# Epoch 43/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0267 - val_accuracy: 0.9869 - val_loss: 0.0402
# Epoch 44/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0260 - val_accuracy: 0.9856 - val_loss: 0.0437
# Epoch 45/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0264 - val_accuracy: 0.9873 - val_loss: 0.0379
# Epoch 46/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9913 - loss: 0.0267 - val_accuracy: 0.9863 - val_loss: 0.0399
# Epoch 47/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0262 - val_accuracy: 0.9866 - val_loss: 0.0401
# Epoch 48/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0263 - val_accuracy: 0.9873 - val_loss: 0.0390
# Epoch 49/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9912 - loss: 0.0263 - val_accuracy: 0.9866 - val_loss: 0.0375
# Epoch 50/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0263 - val_accuracy: 0.9869 - val_loss: 0.0386

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0276
# Test Loss: 0.02762841247022152
# Test Accuracy: 0.9909265637397766
# Accuracy: 99.09%

# %%
import joblib

# ANN model save
model.save("rice_ann_model.keras")

# Scaler save
joblib.dump(scaler, "scaler.pkl")

print("Model and scaler saved successfully!")
# Out:
# Model and scaler saved successfully!

# %%
scaler = joblib.load("scaler.pkl")
